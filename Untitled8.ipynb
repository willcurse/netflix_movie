# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %% [markdown]
# # 1: Data Collection

# %% [markdown]
# 1.1 Data Loading

# %%
data=pd.read_csv(r'C:\Users\Administrator\Desktop\DA-jupyter\netflix_movies.csv')
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# 1.2: Null Data Checking

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# 1.3: Remove Missing Values (Row/Column Deletion)

# %%
data['director'].fillna('Unknown', inplace=True)
data['cast'].fillna('Unknown', inplace=True)
data['country'].fillna('Unknown', inplace=True)
data['date_added'].fillna('Unknown', inplace=True)

# Step 2: Convert 'date_added' to datetime format, replacing 'Unknown' with NaT (Not a Time) to handle non-date values.
data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')

data.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %% [markdown]
# 1.4: find data describe

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# ...

# %% [markdown]
# # 3: Data Analysis

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # 3.1: What is the distribution of content types (Movies vs. TV Shows)?

# %%
movie_count = data[data['type'] == 'Movie'].shape[0]
tv_show_count = data[data['type'] == 'TV Show'].shape[0]
total_count = data['type'].count()

print(f'Total movies are {movie_count}')
print(f'Total TV shows are {tv_show_count}')
print(f'Total content count is {total_count}')

# Prepare the data for plotting
content_counts = pd.DataFrame({
    'Content Type': ['Movies', 'TV Shows'],
    'Count': [movie_count, tv_show_count]
})

# Create a barplot
plt.figure(figsize=(10,6))
sns.barplot(x='Content Type', y='Count', data=content_counts)
plt.title('Distribution of Content Types (Movies vs. TV Shows)')
plt.show()
# Out:
# Total movies are 6131
# Total TV shows are 2676
# Total content count is 8807

# %% [markdown]
# # 3.2. How has the number of titles added to Netflix changed over time?

# %%
# Ensure 'date_added' is in datetime format and extract the year
data['date_added'] = pd.to_datetime(data['date_added'], errors='coerce')
data['year'] = pd.DatetimeIndex(data['date_added']).year

# Group by year and count the number of titles added
titles_per_year = data.groupby('year').size().reset_index(name='count')

# Plot the number of titles added over time
plt.figure(figsize=(10,6))
sns.lineplot(x='year', y='count', data=titles_per_year)
plt.title('How the Number of Titles Added to Netflix Changed Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 3.3: What are the top 10 countries producing the most content on Netflix?

# %%
top_10_countries=data['country'].value_counts().head(10).reset_index()
top_10_countries.columns=['country','count']

plt.figure(figsize=(10,6))
sns.barplot(x='country',y='count',data=top_10_countries)
plt.title('The top 10 countries producing the most content on Netflix?')
plt.show()

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # 3.4: What are the most common ratings given to Netflix content?

# %%
data['rating'].value_counts().reset_index()
# Out:
#        index  rating
# 0      TV-MA    3207
# 1      TV-14    2160
# 2      TV-PG     863
# 3          R     799
# 4      PG-13     490
# 5      TV-Y7     334
# 6       TV-Y     307
# 7         PG     287
# 8       TV-G     220
# 9         NR      80
# 10         G      41
# 11  TV-Y7-FV       6
# 12     NC-17       3
# 13        UR       3
# 14    74 min       1
# 15    84 min       1
# 16    66 min       1

# %% [markdown]
# # 3.5. Which year had the most content releases?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
most_title=data['release_year'].value_counts().reset_index().head(10)
print(most_title)
most_title.columns=['release_year','count']

plt.figure(figsize=(10,6))
sns.barplot(x='release_year',y='count',data=most_title)
plt.title('Which year had the most content releases?')
plt.show()
# Out:
#    index  release_year
# 0   2018          1147
# 1   2017          1032
# 2   2019          1030
# 3   2020           953
# 4   2016           902
# 5   2021           592
# 6   2015           560
# 7   2014           352
# 8   2013           288
# 9   2012           237

# %% [markdown]
# # 3.6: How many seasons do TV Shows typically have on Netflix?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
duration=data['duration'].value_counts().reset_index().head(10)
duration.columns=['duration','index']

plt.figure(figsize=(10, 6)) 
sns.histplot(x='duration', data=duration, bins=30, kde=True) 
plt.title('How Many Seasons Do TV Shows Typically Have on Netflix?')
plt.xlabel('Number of Seasons')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 3.7: Which genres/categories are most common on Netflix?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
listed_data=data['listed_in'].value_counts().reset_index().head(10)
listed_data.columns=['index','listed_in']

plt.figure(figsize=(10,6))
sns.barplot(x='listed_in',y='index',data=listed_data)
plt.title('Which genres/categories are most common on Netflix?')
plt.show()

# %% [markdown]
# # 3.8:  What is the relationship between content rating and release year?

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
data['release_year'] = pd.to_numeric(data['release_year'], errors='coerce')
data['rating'] = data['rating'].astype(str) 
group_data = data.groupby(['release_year', 'rating']).size().reset_index(name='count')

plt.figure(figsize=(12, 8))
pivot_table = group_data.pivot("release_year", "rating", "count")
sns.heatmap(pivot_table, cmap='viridis', annot=True, fmt='g', cbar_kws={'label': 'Number of Titles'})
plt.title('Relationship Between Content Rating and Release Year')
plt.xlabel('Content Rating')
plt.ylabel('Release Year')
plt.xticks(rotation=45)
plt.show()

sns.histplot(x='release_year',y='rating',data=group_data)
plt.title('Relationship Between Content Rating and Release Year')
plt.xlabel('Content Rating')
plt.ylabel('Release Year')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11016\1059540255.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_table = group_data.pivot("release_year", "rating", "count")
